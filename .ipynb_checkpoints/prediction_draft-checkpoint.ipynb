# %%
# %matplotlib inline
from beep.structure.cli import auto_load_processed
from beep.structure.cli import auto_load
import json
import numpy as np
import pandas as pd
from monty.serialization import loadfn, dumpfn
from glob import glob
from datetime import datetime

import matplotlib.pyplot as plt
from matplotlib import cm,colors
import seaborn as sns
import os
# from throughput_dev_tri import get_threshold_targets
import pickle
from scipy.interpolate import interp1d
from scipy import optimize
from scipy.optimize import differential_evolution
# from dtw import *
# from IntracellAnalysis import *
import itertools
# from beep.dataset import BeepDataset
from functools import reduce

import os

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn import linear_model

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error,mean_squared_error,mean_absolute_percentage_error

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, median_absolute_error
from sklearn.dummy import DummyRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import LeaveOneOut 
from sklearn.model_selection import cross_val_score,KFold

from sklearn.neural_network import MLPRegressor
from sklearn.datasets import make_regression

from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

from sklearn.svm import SVR
from keras.layers import Dense, Activation
from keras.models import Sequential
from sklearn.kernel_ridge import KernelRidge
import shap 
# Set the number of neurons/nodes for each layer:
from keras.models import Sequential
from keras.layers import Dense, Activation
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras import regularizers

# %%
X_train  = pd.read_csv("split_1_train_X_Tesla_Cells_20220428.csv")
X_test  = pd.read_csv("split_1_test_X_Tesla_Cells_20220428.csv")
y_train  = pd.read_csv("split_1_train_y_Tesla_Cells_20220428.csv")
y_test  = pd.read_csv("split_1_test_y_Tesla_Cells_20220428.csv")

# %%
y_train['rpt_0.2Cdischarge_capacity0.8_real_regular_throughput::DiagnosticProperties'].hist()
y_test['rpt_0.2Cdischarge_capacity0.8_real_regular_throughput::DiagnosticProperties'].hist(alpha = 0.5)
plt.xlabel('Cumulative Capacity Throughtput')
plt.ylabel('Counts')
legend = ['train set','test set']
plt.legend(legend)
plt.title('Data distribution')
# plt.savefig('data distribution.png')

# %%
X_train = X_train.drop('filename', axis = 1)
X_test = X_test.drop('filename', axis = 1)
y_test = y_test.drop('filename', axis = 1)
y_train = y_train.drop('filename', axis = 1)

# X_train = X_train.to_numpy()
# y_train = y_train.to_numpy()
# X_test = X_test.to_numpy()
# y_test = y_test.to_numpy()

# %%
y_train = np.ravel(y_train)
y_test = np.ravel(y_test)

# %% [markdown]
# ### Feature Scaling

# %%
scaler = StandardScaler()
scaler.fit(X_train)
scaled_x_train = scaler.transform(X_train)
scaled_x_test = scaler.transform(X_test)

# %%
norm = MinMaxScaler().fit(X_train)
# transform training data
X_train_norm = norm.transform(X_train)
# transform testing dataabs
X_test_norm = norm.transform(X_test)

# %%
col = 'rpt_0.2Cdischarge_capacity0.8_real_regular_throughput::DiagnosticProperties'
X_train = X_train[y_train[col]<20000]
y_train = y_train[y_train[col]<20000]

# %% [markdown]
# ## Linear regression fit using a dummy model

# %%
# x_train = X_train_norm
# x_test = X_test_norm
x_train = scaled_x_train 
x_test = scaled_x_test

# %%
lm = linear_model.Lasso(alpha = 2)
model = lm.fit(x_train, y_train)
tests = lm.predict(x_test)
trains = lm.predict(x_train)
fig = plt.subplots(dpi = 100)
plt.scatter(y_train, trains, label = 'Train')
plt.scatter(y_test, tests, label = 'Test')

plt.plot(y_train, y_train, color="gold")
plt.ylabel('Predicted Values')
plt.xlabel('Real Values')
plt.title('Lasso Model predictions, using all 365 features')
plt.legend(loc = 'best')
plt.savefig('Lasso_predictions.png')
print('RMSE: ' + str(mean_squared_error(tests, y_test)**0.5), 'MAPE: ' + str(mean_absolute_percentage_error(tests, y_test)))
# Out:
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.515e+07, tolerance: 2.716e+05
# RMSE: 3459.8533640847163 MAPE: 3.852067806404243

# %% [markdown]
# ##### normalizing is better than standardizing

# %% [markdown]
# ### Random Forest

# %%
regr = RandomForestRegressor(max_depth=7, random_state=2)
regr.fit(x_train, y_train)

tests = regr.predict(x_test)
trains = regr.predict(x_train)

fig = plt.subplots(dpi = 100)
plt.scatter(y_train, trains, label = 'Train')
plt.scatter(y_test, tests, label = 'Test')

plt.plot(y_train, y_train,color="gold")
# plt.ylim(0, y_train['rpt_0.2Cdischarge_capacity0.8_real_regular_throughput::DiagnosticProperties'].max())
plt.ylabel('Predicted Values')
plt.xlabel('Real Values')
plt.title('Random Forest Predictions with 365 features')
plt.legend(loc = 'best')
print('MSE: ' + str(mean_squared_error(tests, y_test)**0.5), 'MAPE: ' + str(mean_absolute_percentage_error(tests, y_test)))
# Out:
# MSE: 2905.949388073086 MAPE: 0.32219463838926354

# %%
explainer = shap.TreeExplainer(regr)
shap_values = explainer(X_train)
fig = plt.subplots(dpi = 150)
shap.summary_plot(shap_values, X_train, max_display = 10, show=False, cmap='summer', plot_size=(6,3), sort=True)

# %% [markdown]
# ### After data standardization

# %%
regr = RandomForestRegressor(max_depth=3, random_state=1)
regr.fit(scaled_x_train, y_train)

predictions = regr.predict(scaled_x_test)
trains = regr.predict(scaled_x_train)

fig = plt.subplots(dpi = 100)
plt.scatter(y_train, trains, label = 'trainings')
plt.scatter(y_test, predictions, label = 'predictions')

plt.plot(y_train, y_train,color="gold")
# plt.ylim(0, y_train['rpt_0.2Cdischarge_capacity0.8_real_regular_throughput::DiagnosticProperties'].max())
plt.ylabel('Predicted Values')
plt.xlabel('Real Values')
plt.title('Random Forest Predictions with 365 features')
plt.legend(loc = 'best')

mean_squared_error(predictions, y_test)**0.5
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [263], in <cell line: 2>()
#       1 scaler = StandardScaler()
# ----> 2 scaler.fit(X_train)
#       3 scaled_x_train = scaler.transform(X_train)
#       4 scaled_x_test = scaler.transform(X_test)
#
# File ~/anaconda3/envs/beep-env/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:806, in StandardScaler.fit(self, X, y, sample_weight)
#     804 # Reset internal state before fitting
#     805 self._reset()
# --> 806 return self.partial_fit(X, y, sample_weight)
#
# File ~/anaconda3/envs/beep-env/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:841, in StandardScaler.partial_fit(self, X, y, sample_weight)
#     809 """Online computation of mean and std on X for later scaling.
#     810
#     811 All of X is processed as a single batch. This is intended for cases
#    (...)
#     838     Fitted scaler.
#     839 """
#     840 first_call = not hasattr(self, "n_samples_seen_")
# --> 841 X = self._validate_data(
#     842     X,
#     843     accept_sparse=("csr", "csc"),
#     844     estimator=self,
#     845     dtype=FLOAT_DTYPES,
#     846     force_all_finite="allow-nan",
#     847     reset=first_call,
#     848 )
#     849 n_features = X.shape[1]
#     851 if sample_weight is not None:
#
# File ~/anaconda3/envs/beep-env/lib/python3.8/site-packages/sklearn/base.py:566, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     564     raise ValueError("Validation should be done on X, y or both.")
#     565 elif not no_val_X and no_val_y:
# --> 566     X = check_array(X, **check_params)
#     567     out = X
#     568 elif no_val_X and not no_val_y:
#
# File ~/anaconda3/envs/beep-env/lib/python3.8/site-packages/sklearn/utils/validation.py:746, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744         array = array.astype(dtype, casting="unsafe", copy=False)
#     745     else:
# --> 746         array = np.asarray(array, order=order, dtype=dtype)
#     747 except ComplexWarning as complex_warning:
#     748     raise ValueError(
#     749         "Complex data not supported\n{}\n".format(array)
#     750     ) from complex_warning
#
# ValueError: could not convert string to float: 'PreDiag_000390_0001F4_structure'

# %% [markdown]
# ### Neural Network

# %%
model = Sequential()
model.add(Dense(400, input_dim=364, kernel_initializer='normal', activation='relu'))
#, activity_regularizer=regularizers.L2(0.01)
model.add(Dense(10, kernel_initializer='normal'))
model.add(Dense(1, kernel_initializer='normal'))

# Compile the model and calculate its accuracy:
model.compile(loss='mean_squared_error', optimizer='adam') 

# Print a summary of the Keras model:
# model.summary()
# Out:
# 2022-06-02 18:22:47.321644: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-06-02 18:22:47.321753: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ip-172-16-23-91): /proc/driver/nvidia/version does not exist
# 2022-06-02 18:22:47.323254: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
x_train = scaled_x_train
x_test = scaled_x_test

model.fit(x_train, y_train, epochs=50, batch_size=8)
tests = model.predict(x_test)
trains = model.predict(x_train)

plt.scatter(y_train, trains, label = 'Train')
plt.scatter(y_test, tests, label = 'Test')

plt.plot(y_train, y_train, color="gold")
plt.ylabel('Predicted Values')
plt.xlabel('Real Values')
plt.title('Neural Network with 364 features')
plt.legend(loc = 'best')
print(f'TRAIN: RMSE: {mean_squared_error(trains, y_train)**0.5}, MAPE: {mean_absolute_percentage_error(trains, y_train)}')
print(f'TEST: RMSE: {mean_squared_error(tests, y_test)**0.5}, MAPE: {mean_absolute_percentage_error(tests, y_test)}')
# print('MSE: ' + str(mean_squared_error(predictions, y_test)**0.5), 'MAPE: ' + str(mean_absolute_percentage_error(predictions, y_test)))
# Out:
# Epoch 1/50
# 20/20 [==============================] - 0s 1ms/step - loss: 16467541.0000
# Epoch 2/50
# 20/20 [==============================] - 0s 1ms/step - loss: 9731468.0000
# Epoch 3/50
# 20/20 [==============================] - 0s 1ms/step - loss: 8183822.0000
# Epoch 4/50
# 20/20 [==============================] - 0s 1ms/step - loss: 7083528.5000
# Epoch 5/50
# 20/20 [==============================] - 0s 1ms/step - loss: 6487683.5000
# Epoch 6/50
# 20/20 [==============================] - 0s 1ms/step - loss: 5864476.0000
# Epoch 7/50
# 20/20 [==============================] - 0s 1ms/step - loss: 5468044.5000
# Epoch 8/50
# 20/20 [==============================] - 0s 1ms/step - loss: 5126652.5000
# Epoch 9/50
# 20/20 [==============================] - 0s 1ms/step - loss: 4862150.0000
# Epoch 10/50
# 20/20 [==============================] - 0s 1ms/step - loss: 4576564.0000
# Epoch 11/50
# 20/20 [==============================] - 0s 1ms/step - loss: 4356983.5000
# Epoch 12/50
# 20/20 [==============================] - 0s 1ms/step - loss: 4198029.5000
# Epoch 13/50
# 20/20 [==============================] - 0s 1ms/step - loss: 4047862.5000
# Epoch 14/50
# 20/20 [==============================] - 0s 1ms/step - loss: 3944976.5000
# Epoch 15/50
# 20/20 [==============================] - 0s 1ms/step - loss: 3807902.0000
# Epoch 16/50
# 20/20 [==============================] - 0s 1ms/step - loss: 3697627.7500
# Epoch 17/50
# 20/20 [==============================] - 0s 1ms/step - loss: 3668121.7500
# Epoch 18/50
# 20/20 [==============================] - 0s 1ms/step - loss: 3535099.0000
# Epoch 19/50
# 20/20 [==============================] - 0s 1ms/step - loss: 3496798.2500
# Epoch 20/50
# 20/20 [==============================] - 0s 1ms/step - loss: 3425655.2500
# Epoch 21/50
# 20/20 [==============================] - 0s 1ms/step - loss: 3391523.2500
# Epoch 22/50
# 20/20 [==============================] - 0s 1ms/step - loss: 3334023.5000
# Epoch 23/50
# 20/20 [==============================] - 0s 1ms/step - loss: 3190615.2500
# Epoch 24/50
# 20/20 [==============================] - 0s 1ms/step - loss: 3154509.0000
# Epoch 25/50
# 20/20 [==============================] - 0s 1ms/step - loss: 3134314.5000
# Epoch 26/50
# 20/20 [==============================] - 0s 1ms/step - loss: 3046515.5000
# Epoch 27/50
# 20/20 [==============================] - 0s 1ms/step - loss: 3033103.5000
# Epoch 28/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2949139.7500
# Epoch 29/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2951821.5000
# Epoch 30/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2906104.7500
# Epoch 31/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2895336.5000
# Epoch 32/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2802967.5000
# Epoch 33/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2773240.2500
# Epoch 34/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2760816.5000
# Epoch 35/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2689664.2500
# Epoch 36/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2633209.7500
# Epoch 37/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2606552.0000
# Epoch 38/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2578307.0000
# Epoch 39/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2568398.5000
# Epoch 40/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2514220.0000
# Epoch 41/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2454883.0000
# Epoch 42/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2494185.2500
# Epoch 43/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2432567.7500
# Epoch 44/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2391361.0000
# Epoch 45/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2351770.5000
# Epoch 46/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2308736.2500
# Epoch 47/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2308466.0000
# Epoch 48/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2263001.5000
# Epoch 49/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2278682.7500
# Epoch 50/50
# 20/20 [==============================] - 0s 1ms/step - loss: 2222316.5000
# 2/2 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 1ms/step
# TRAIN: RMSE: 1463.9053194271532, MAPE: 0.2549419936416553
# TEST: RMSE: 4211.651037430682, MAPE: 0.48312221887505885

# %% [markdown]
# ##### standardizing is better than normalizing

# %% [markdown]
# ### Kernel Method

# %%
def kernel_model(x_train, x_test, y_train, y_test):

    scaled_x_train = np.concatenate((x_train, np.ones((x_train.shape[0], 1))), axis=-1)
    scaled_x_test = np.concatenate((x_test, np.ones((x_test.shape[0], 1))), axis=-1)

    rng = np.random.RandomState(0)
    krr = KernelRidge(alpha=0.32, kernel = 'laplacian')
    y_train = np.ravel(y_train)
    y_test = np.ravel(y_test)
    krr.fit(scaled_x_train, y_train)
    predictions = krr.predict(scaled_x_test)
    trains = krr.predict(scaled_x_train)
    
    X_train_summary = shap.kmeans(scaled_x_train, 10)
    
    explainer = shap.KernelExplainer(krr.predict, data = X_train_summary)
    shap_values = explainer(scaled_x_train[0,:])
    fig = plt.subplots(dpi = 150)
    shap.summary_plot(shap_values, X_train, max_display = 10, show=False, cmap='summer', plot_size=(6,3), sort=True)

    fig = plt.subplots(dpi = 150)
    # trains = np.exp(trains)
    # predictions = np.exp(predictions)
    # plt.scatter(np.exp(y_train), trains, label = 'trainings')
    # plt.scatter(np.exp(y_test), predictions, label = 'predictions')

    plt.plot(y_train, y_train, color="gold")
    # plt.ylim(0, y_train['rpt_0.2Cdischarge_capacity0.8_real_regular_throughput::DiagnosticProperties'].max())
    plt.ylabel('Predicted Values')
    plt.xlabel('Real Values')
    plt.title('Kernel with 365 features')

#     print('RMSE: ' + str(mean_squared_error(predictions, y_test)**0.5), 'MAPE: ' + str(mean_absolute_percentage_error(predictions, y_test)))
    #mean_absolute_error(predictions, y_test)
    
    plt.scatter(y_train, trains, label = 'Train' + ' MAPE:' + 
                "{:.2f}".format(mean_absolute_percentage_error(trains, y_train)) + 
                '|RMSE:' + "{:.0f}".format(mean_squared_error(trains, y_train)**0.5))
    plt.scatter(y_test, predictions, label = 'Test ' + 'MAPE:' + 
                "{:.2f}".format(mean_absolute_percentage_error(predictions, y_test)) + 
                '|RMSE:' + "{:.0f}".format(mean_squared_error(predictions, y_test)**0.5))
    
    plt.legend(loc = 'best')

# %%
kernel_model(x_train, x_test, y_train, y_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [64], in <cell line: 1>()
# ----> 1 kernel_model(x_train, x_test, y_train, y_test)
#
# Input In [63], in kernel_model(x_train, x_test, y_train, y_test)
#      14 X_train_summary = shap.kmeans(scaled_x_train, 10)
#      16 explainer = shap.KernelExplainer(krr.predict, data = X_train_summary)
# ---> 17 shap_values = explainer(scaled_x_train.iloc[0,:])
#      18 fig = plt.subplots(dpi = 150)
#      19 shap.summary_plot(shap_values, X_train, max_display = 10, show=False, cmap='summer', plot_size=(6,3), sort=True)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iloc'

# %%
scaled_x_train = np.concatenate((x_train, np.ones((x_train.shape[0], 1))), axis=-1)
scaled_x_test = np.concatenate((x_test, np.ones((x_test.shape[0], 1))), axis=-1)

rng = np.random.RandomState(0)
krr = KernelRidge(alpha=0.2, kernel = 'laplacian')
y_train = np.ravel(y_train)
y_test = np.ravel(y_test)
krr.fit(scaled_x_train, y_train)
predictions = krr.predict(scaled_x_test)
trains = krr.predict(scaled_x_train)

fig = plt.subplots(dpi = 100)
# trains = np.exp(trains)
# predictions = np.exp(predictions)
# plt.scatter(np.exp(y_train), trains, label = 'trainings')
# plt.scatter(np.exp(y_test), predictions, label = 'predictions')

plt.scatter(y_train, trains, label = 'trainings')
plt.scatter(y_test, predictions, label = 'predictions')

plt.plot(y_train, y_train, color="gold")
# plt.ylim(0, y_train['rpt_0.2Cdischarge_capacity0.8_real_regular_throughput::DiagnosticProperties'].max())
plt.ylabel('Predicted Values')
plt.xlabel('Real Values')
plt.title('Kernel with 365 features')
plt.legend(loc = 'best')

print('MSE: ' + str(mean_squared_error(predictions, y_test)**0.5), 'MAPE: ' + str(mean_absolute_percentage_error(predictions, y_test)))
#mean_absolute_error(predictions, y_test)
# Out:
# MSE: 2698.1121149500946 MAPE: 0.31537951754569715

# %% [markdown]
# ##### standardizing or normalizing have similar performance

# %%
explainer = shap.KernelExplainer(regr)
shap_values = explainer(X_train)
fig = plt.subplots(dpi = 150)
shap.summary_plot(shap_values, X_train, max_display = 10, show=False, cmap='summer', plot_size=(6,3), sort=True)

# %% [markdown]
# ### Cross validation

# %%
X = np.concatenate((X_train.to_numpy(), X_test.to_numpy()))
y = np.concatenate((y_train.to_numpy(), y_test.to_numpy()))

# %%
kf = KFold(n_splits=5, shuffle = True) # split into 5 folds 
kf.get_n_splits(X) # returns the number of splitting iterations in the cross-validator
errors = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    fig, ax = plt.subplots(1,2, figsize=(2*6, 1*4) )
    ax[0].hist(y_train)
    ax[0].hist(y_test, alpha = 0.5)
    lm = linear_model.LinearRegression()
    model = lm.fit(X_train, y_train)
    predictions = lm.predict(X_test)
    error = mean_squared_error(predictions, y_test)
    errors.append(error)
    ax[1].scatter(y_test, predictions, label = 'predictions')
    ax[1].scatter(y_train, lm.predict(X_train), label = 'trainings')
    ax[1].set_ylim(0, y_train.max())
score=cross_val_score(lm,X_train,y_train,cv=kf)

print(np.mean(errors),score.mean())
# Out:
# 1687772589.752465 -127.44842905937249

# %% [markdown]
# #### First correlation test with Variance feature (Severson 2019)

# %%
variance_feat = x_train['var_discharging_capacity::CycleSummaryStats'].tolist()
train_labels= y_train["rpt_0.2Cdischarge_capacity0.8_real_regular_throughput::DiagnosticProperties"].tolist()

# %%
a,b = np.polyfit(variance_feat, train_labels,1 )
plt.plot(variance_feat, train_labels,'x',color='gold')
plt.plot([min(variance_feat),max(variance_feat)],[min(variance_feat)*a+b,a*max(variance_feat)+b],color = "cyan")
plt.xlabel('Main Variance feature')
plt.ylabel('Label: Total capacity throughput')
plt.title('Variance feature correlation ?')

coef = np.corrcoef(variance_feat,train_labels)[0,1]
print(coef)
# Out:
# -0.6100447029609648

# %%
##For comparison, the non_log feature of the variance is not as good:
non_log_feat = np.exp(np.asarray(variance_feat))
coef = np.corrcoef(non_log_feat,train_labels)[0,1]
print (coef)
# Out:
# -0.5459908068807883

# %% [markdown]
# #### Automating calculations of all correlation coeff for all features

# %%
def get_coef (feat,labels, plot = False):
    ### input: feature list, labels list, 
    ### return correlation coef between the feature and the labels
    
    a,b = np.polyfit(feat,labels,1 )
    coef = np.corrcoef(variance_feat,train_labels)[0,1]
    if plot:
        plt.plot(feat, labels,'x',color='gold')
        plt.plot([min(feat),max(feat)],[min(feat)*a+b,a*max(feat)+b],color = "cyan")
        plt.xlabel('Main Variance feature')
        plt.ylabel('Label: Total capacity throughput')
        plt.title('Variance feature correlation ?')
        print (f'correlation coef between the feature and the labels is {coef}')
    return coef

# %%
get_coef(variance_feat,train_labels)
# Out:
# -0.6100447029609648

# %%
#next :
coef_dict ={}
i=0
for key in x_train.keys():
    if i== 0:#first is filename...
        i+=1
        continue
    feature= x_train[key].tolist()
    coef = np.corrcoef(feature, train_labels)[0,1]
    coef_dict[key]=abs(coef)

coef_dict = dict(sorted(coef_dict.items(), key=lambda item: item[1],reverse=True))

##printing a few: 
i=0
for key in coef_dict.keys():
    if i<10:
        print(f'feature: {key} gives a correlation of {coef_dict[key]}')
        i+=1
    
# print(f'First examples of the coef_dict are {list(coef_dict.items())[:10]}')
# Out:
# feature: abs_discharging_capacity::CycleSummaryStats gives a correlation of 0.7587100552701532
# feature: square_discharging_capacity::CycleSummaryStats gives a correlation of 0.7299191120436507
# feature: abs_mean_discharge_capacity_difference_cycles_2:100::DeltaQFastCharge gives a correlation of 0.7219953391133521
# feature: mean_discharging_capacity::CycleSummaryStats gives a correlation of 0.7218496725963969
# feature: abs_charging_capacity::DiagnosticSummaryStats gives a correlation of 0.6839188370424999
# feature: abs_charging_energy::DiagnosticSummaryStats gives a correlation of 0.681545930799766
# feature: abs_min_discharge_capacity_difference_cycles_2:100::DeltaQFastCharge gives a correlation of 0.6703448832561698
# feature: diag_1_pe_voltage_FC4p2V::IntracellFeaturesV2 gives a correlation of 0.6651322632746888
# feature: D_4::HPPCResistanceVoltageFeatures gives a correlation of 0.6487567927233764
# feature: abs_variance_discharge_capacity_difference_cycles_2:100::DeltaQFastCharge gives a correlation of 0.6027924164769486

# %% [markdown]
# #### Below is the list of features for reference

# %%
for key in x_train.keys():
    print (key)
# Out:
# filename
# D_1::HPPCResistanceVoltageFeatures
# D_2::HPPCResistanceVoltageFeatures
# D_3::HPPCResistanceVoltageFeatures
# D_4::HPPCResistanceVoltageFeatures
# D_5::HPPCResistanceVoltageFeatures
# D_6::HPPCResistanceVoltageFeatures
# D_7::HPPCResistanceVoltageFeatures
# D_8::HPPCResistanceVoltageFeatures
# SOC20%_degrad50%::HPPCRelaxationFeatures
# SOC20%_degrad80%::HPPCRelaxationFeatures
# SOC20%_degrad99%::HPPCRelaxationFeatures
# SOC30%_degrad50%::HPPCRelaxationFeatures
# SOC30%_degrad80%::HPPCRelaxationFeatures
# SOC30%_degrad99%::HPPCRelaxationFeatures
# SOC40%_degrad50%::HPPCRelaxationFeatures
# SOC40%_degrad80%::HPPCRelaxationFeatures
# SOC40%_degrad99%::HPPCRelaxationFeatures
# SOC50%_degrad50%::HPPCRelaxationFeatures
# SOC50%_degrad80%::HPPCRelaxationFeatures
# SOC50%_degrad99%::HPPCRelaxationFeatures
# SOC60%_degrad50%::HPPCRelaxationFeatures
# SOC60%_degrad80%::HPPCRelaxationFeatures
# SOC60%_degrad99%::HPPCRelaxationFeatures
# SOC70%_degrad50%::HPPCRelaxationFeatures
# SOC70%_degrad80%::HPPCRelaxationFeatures
# SOC70%_degrad99%::HPPCRelaxationFeatures
# SOC80%_degrad50%::HPPCRelaxationFeatures
# SOC80%_degrad80%::HPPCRelaxationFeatures
# SOC80%_degrad99%::HPPCRelaxationFeatures
# SOC90%_degrad50%::HPPCRelaxationFeatures
# SOC90%_degrad80%::HPPCRelaxationFeatures
# SOC90%_degrad99%::HPPCRelaxationFeatures
# abs_charging_capacity::DiagnosticSummaryStats
# abs_charging_dQdV::DiagnosticSummaryStats
# abs_charging_energy::CycleSummaryStats
# abs_charging_energy::DiagnosticSummaryStats
# abs_discharging_capacity::CycleSummaryStats
# abs_discharging_capacity::DiagnosticSummaryStats
# abs_discharging_dQdV::DiagnosticSummaryStats
# abs_discharging_energy::DiagnosticSummaryStats
# abs_mean_discharge_capacity_difference_cycles_2:100::DeltaQFastCharge
# abs_min_discharge_capacity_difference_cycles_2:100::DeltaQFastCharge
# abs_variance_discharge_capacity_difference_cycles_2:100::DeltaQFastCharge
# diag_0_LLI_opt::IntracellFeaturesV2
# diag_0_Q_fc::IntracellFeaturesV2
# diag_0_Q_li::IntracellFeaturesV2
# diag_0_Q_ne::IntracellFeaturesV2
# diag_0_Q_ne_opt::IntracellFeaturesV2
# diag_0_Q_pe::IntracellFeaturesV2
# diag_0_Q_pe_opt::IntracellFeaturesV2
# diag_0_ne_soc_FC2p7V::IntracellFeaturesV2
# diag_0_ne_soc_FC2p8V::IntracellFeaturesV2
# diag_0_ne_soc_FC2p9V::IntracellFeaturesV2
# diag_0_ne_soc_FC3p0V::IntracellFeaturesV2
# diag_0_ne_soc_FC3p1V::IntracellFeaturesV2
# diag_0_ne_soc_FC3p2V::IntracellFeaturesV2
# diag_0_ne_soc_FC3p3V::IntracellFeaturesV2
# diag_0_ne_soc_FC3p4V::IntracellFeaturesV2
# diag_0_ne_soc_FC3p5V::IntracellFeaturesV2
# diag_0_ne_soc_FC3p6V::IntracellFeaturesV2
# diag_0_ne_soc_FC3p7V::IntracellFeaturesV2
# diag_0_ne_soc_FC3p8V::IntracellFeaturesV2
# diag_0_ne_soc_FC3p9V::IntracellFeaturesV2
# diag_0_ne_soc_FC4p0V::IntracellFeaturesV2
# diag_0_ne_soc_FC4p1V::IntracellFeaturesV2
# diag_0_ne_soc_FC4p2V::IntracellFeaturesV2
# diag_0_ne_voltage_FC2p7V::IntracellFeaturesV2
# diag_0_ne_voltage_FC2p8V::IntracellFeaturesV2
# diag_0_ne_voltage_FC2p9V::IntracellFeaturesV2
# diag_0_ne_voltage_FC3p0V::IntracellFeaturesV2
# diag_0_ne_voltage_FC3p1V::IntracellFeaturesV2
# diag_0_ne_voltage_FC3p2V::IntracellFeaturesV2
# diag_0_ne_voltage_FC3p3V::IntracellFeaturesV2
# diag_0_ne_voltage_FC3p4V::IntracellFeaturesV2
# diag_0_ne_voltage_FC3p5V::IntracellFeaturesV2
# diag_0_ne_voltage_FC3p6V::IntracellFeaturesV2
# diag_0_ne_voltage_FC3p7V::IntracellFeaturesV2
# diag_0_ne_voltage_FC3p8V::IntracellFeaturesV2
# diag_0_ne_voltage_FC3p9V::IntracellFeaturesV2
# diag_0_ne_voltage_FC4p0V::IntracellFeaturesV2
# diag_0_ne_voltage_FC4p1V::IntracellFeaturesV2
# diag_0_ne_voltage_FC4p2V::IntracellFeaturesV2
# diag_0_pe_soc_FC2p7V::IntracellFeaturesV2
# diag_0_pe_soc_FC2p8V::IntracellFeaturesV2
# diag_0_pe_soc_FC2p9V::IntracellFeaturesV2
# diag_0_pe_soc_FC3p0V::IntracellFeaturesV2
# diag_0_pe_soc_FC3p1V::IntracellFeaturesV2
# diag_0_pe_soc_FC3p2V::IntracellFeaturesV2
# diag_0_pe_soc_FC3p3V::IntracellFeaturesV2
# diag_0_pe_soc_FC3p4V::IntracellFeaturesV2
# diag_0_pe_soc_FC3p5V::IntracellFeaturesV2
# diag_0_pe_soc_FC3p6V::IntracellFeaturesV2
# diag_0_pe_soc_FC3p7V::IntracellFeaturesV2
# diag_0_pe_soc_FC3p8V::IntracellFeaturesV2
# diag_0_pe_soc_FC3p9V::IntracellFeaturesV2
# diag_0_pe_soc_FC4p0V::IntracellFeaturesV2
# diag_0_pe_soc_FC4p1V::IntracellFeaturesV2
# diag_0_pe_soc_FC4p2V::IntracellFeaturesV2
# diag_0_pe_voltage_FC2p7V::IntracellFeaturesV2
# diag_0_pe_voltage_FC2p8V::IntracellFeaturesV2
# diag_0_pe_voltage_FC2p9V::IntracellFeaturesV2
# diag_0_pe_voltage_FC3p0V::IntracellFeaturesV2
# diag_0_pe_voltage_FC3p1V::IntracellFeaturesV2
# diag_0_pe_voltage_FC3p2V::IntracellFeaturesV2
# diag_0_pe_voltage_FC3p3V::IntracellFeaturesV2
# diag_0_pe_voltage_FC3p4V::IntracellFeaturesV2
# diag_0_pe_voltage_FC3p5V::IntracellFeaturesV2
# diag_0_pe_voltage_FC3p6V::IntracellFeaturesV2
# diag_0_pe_voltage_FC3p7V::IntracellFeaturesV2
# diag_0_pe_voltage_FC3p8V::IntracellFeaturesV2
# diag_0_pe_voltage_FC3p9V::IntracellFeaturesV2
# diag_0_pe_voltage_FC4p0V::IntracellFeaturesV2
# diag_0_pe_voltage_FC4p1V::IntracellFeaturesV2
# diag_0_pe_voltage_FC4p2V::IntracellFeaturesV2
# diag_0_rmse_error::IntracellFeaturesV2
# diag_0_x_NE_2::IntracellFeaturesV2
# diag_1_LLI_opt::IntracellFeaturesV2
# diag_1_Q_fc::IntracellFeaturesV2
# diag_1_Q_li::IntracellFeaturesV2
# diag_1_Q_ne::IntracellFeaturesV2
# diag_1_Q_ne_opt::IntracellFeaturesV2
# diag_1_Q_pe::IntracellFeaturesV2
# diag_1_Q_pe_opt::IntracellFeaturesV2
# diag_1_ne_soc_FC2p7V::IntracellFeaturesV2
# diag_1_ne_soc_FC2p8V::IntracellFeaturesV2
# diag_1_ne_soc_FC2p9V::IntracellFeaturesV2
# diag_1_ne_soc_FC3p0V::IntracellFeaturesV2
# diag_1_ne_soc_FC3p1V::IntracellFeaturesV2
# diag_1_ne_soc_FC3p2V::IntracellFeaturesV2
# diag_1_ne_soc_FC3p3V::IntracellFeaturesV2
# diag_1_ne_soc_FC3p4V::IntracellFeaturesV2
# diag_1_ne_soc_FC3p5V::IntracellFeaturesV2
# diag_1_ne_soc_FC3p6V::IntracellFeaturesV2
# diag_1_ne_soc_FC3p7V::IntracellFeaturesV2
# diag_1_ne_soc_FC3p8V::IntracellFeaturesV2
# diag_1_ne_soc_FC3p9V::IntracellFeaturesV2
# diag_1_ne_soc_FC4p0V::IntracellFeaturesV2
# diag_1_ne_soc_FC4p1V::IntracellFeaturesV2
# diag_1_ne_soc_FC4p2V::IntracellFeaturesV2
# diag_1_ne_voltage_FC2p7V::IntracellFeaturesV2
# diag_1_ne_voltage_FC2p8V::IntracellFeaturesV2
# diag_1_ne_voltage_FC2p9V::IntracellFeaturesV2
# diag_1_ne_voltage_FC3p0V::IntracellFeaturesV2
# diag_1_ne_voltage_FC3p1V::IntracellFeaturesV2
# diag_1_ne_voltage_FC3p2V::IntracellFeaturesV2
# diag_1_ne_voltage_FC3p3V::IntracellFeaturesV2
# diag_1_ne_voltage_FC3p4V::IntracellFeaturesV2
# diag_1_ne_voltage_FC3p5V::IntracellFeaturesV2
# diag_1_ne_voltage_FC3p6V::IntracellFeaturesV2
# diag_1_ne_voltage_FC3p7V::IntracellFeaturesV2
# diag_1_ne_voltage_FC3p8V::IntracellFeaturesV2
# diag_1_ne_voltage_FC3p9V::IntracellFeaturesV2
# diag_1_ne_voltage_FC4p0V::IntracellFeaturesV2
# diag_1_ne_voltage_FC4p1V::IntracellFeaturesV2
# diag_1_ne_voltage_FC4p2V::IntracellFeaturesV2
# diag_1_pe_soc_FC2p7V::IntracellFeaturesV2
# diag_1_pe_soc_FC2p8V::IntracellFeaturesV2
# diag_1_pe_soc_FC2p9V::IntracellFeaturesV2
# diag_1_pe_soc_FC3p0V::IntracellFeaturesV2
# diag_1_pe_soc_FC3p1V::IntracellFeaturesV2
# diag_1_pe_soc_FC3p2V::IntracellFeaturesV2
# diag_1_pe_soc_FC3p3V::IntracellFeaturesV2
# diag_1_pe_soc_FC3p4V::IntracellFeaturesV2
# diag_1_pe_soc_FC3p5V::IntracellFeaturesV2
# diag_1_pe_soc_FC3p6V::IntracellFeaturesV2
# diag_1_pe_soc_FC3p7V::IntracellFeaturesV2
# diag_1_pe_soc_FC3p8V::IntracellFeaturesV2
# diag_1_pe_soc_FC3p9V::IntracellFeaturesV2
# diag_1_pe_soc_FC4p0V::IntracellFeaturesV2
# diag_1_pe_soc_FC4p1V::IntracellFeaturesV2
# diag_1_pe_soc_FC4p2V::IntracellFeaturesV2
# diag_1_pe_voltage_FC2p7V::IntracellFeaturesV2
# diag_1_pe_voltage_FC2p8V::IntracellFeaturesV2
# diag_1_pe_voltage_FC2p9V::IntracellFeaturesV2
# diag_1_pe_voltage_FC3p0V::IntracellFeaturesV2
# diag_1_pe_voltage_FC3p1V::IntracellFeaturesV2
# diag_1_pe_voltage_FC3p2V::IntracellFeaturesV2
# diag_1_pe_voltage_FC3p3V::IntracellFeaturesV2
# diag_1_pe_voltage_FC3p4V::IntracellFeaturesV2
# diag_1_pe_voltage_FC3p5V::IntracellFeaturesV2
# diag_1_pe_voltage_FC3p6V::IntracellFeaturesV2
# diag_1_pe_voltage_FC3p7V::IntracellFeaturesV2
# diag_1_pe_voltage_FC3p8V::IntracellFeaturesV2
# diag_1_pe_voltage_FC3p9V::IntracellFeaturesV2
# diag_1_pe_voltage_FC4p0V::IntracellFeaturesV2
# diag_1_pe_voltage_FC4p1V::IntracellFeaturesV2
# diag_1_pe_voltage_FC4p2V::IntracellFeaturesV2
# diag_1_rmse_error::IntracellFeaturesV2
# diag_1_x_NE_2::IntracellFeaturesV2
# diag_sum_diff_0_1_rpt_0.2Ccharge_capacity::DiagnosticSummaryStats
# diag_sum_diff_0_1_rpt_0.2Ccharge_energy::DiagnosticSummaryStats
# diag_sum_diff_0_1_rpt_0.2Cdischarge_capacity::DiagnosticSummaryStats
# diag_sum_diff_0_1_rpt_0.2Cdischarge_energy::DiagnosticSummaryStats
# diag_sum_diff_0_1_rpt_1Ccharge_capacity::DiagnosticSummaryStats
# diag_sum_diff_0_1_rpt_1Ccharge_energy::DiagnosticSummaryStats
# diag_sum_diff_0_1_rpt_1Cdischarge_capacity::DiagnosticSummaryStats
# diag_sum_diff_0_1_rpt_1Cdischarge_energy::DiagnosticSummaryStats
# diag_sum_diff_0_1_rpt_2Ccharge_capacity::DiagnosticSummaryStats
# diag_sum_diff_0_1_rpt_2Ccharge_energy::DiagnosticSummaryStats
# diag_sum_diff_0_1_rpt_2Cdischarge_capacity::DiagnosticSummaryStats
# diag_sum_diff_0_1_rpt_2Cdischarge_energy::DiagnosticSummaryStats
# discharge_capacity_cycle_100::DeltaQFastCharge
# discharge_capacity_cycle_2::DeltaQFastCharge
# integrated_time_temperature_cycles_1:100::DeltaQFastCharge
# intercept_discharge_capacity_cycle_number_2:100::DeltaQFastCharge
# intercept_discharge_capacity_cycle_number_91:100::DeltaQFastCharge
# internal_resistance_cycle_2::DeltaQFastCharge
# internal_resistance_difference_cycles_2:100::DeltaQFastCharge
# kurtosis_charging_capacity::DiagnosticSummaryStats
# kurtosis_charging_dQdV::DiagnosticSummaryStats
# kurtosis_charging_energy::CycleSummaryStats
# kurtosis_charging_energy::DiagnosticSummaryStats
# kurtosis_discharging_capacity::CycleSummaryStats
# kurtosis_discharging_capacity::DiagnosticSummaryStats
# kurtosis_discharging_dQdV::DiagnosticSummaryStats
# kurtosis_discharging_energy::DiagnosticSummaryStats
# kurtosis_ocv::HPPCResistanceVoltageFeatures
# kurtosis_v_diff::HPPCResistanceVoltageFeatures
# m0_Amp_rpt_0.2C_1::RPTdQdVFeatures
# m0_Mu_rpt_0.2C_1::RPTdQdVFeatures
# m1_Amp_rpt_0.2C_1::RPTdQdVFeatures
# m1_Mu_rpt_0.2C_1::RPTdQdVFeatures
# m2_Amp_rpt_0.2C_1::RPTdQdVFeatures
# m2_Mu_rpt_0.2C_1::RPTdQdVFeatures
# m3_Amp_rpt_0.2C_1::RPTdQdVFeatures
# m3_Mu_rpt_0.2C_1::RPTdQdVFeatures
# max_discharge_capacity_difference::DeltaQFastCharge
# mean_charging_capacity::DiagnosticSummaryStats
# mean_charging_dQdV::DiagnosticSummaryStats
# mean_charging_energy::CycleSummaryStats
# mean_charging_energy::DiagnosticSummaryStats
# mean_discharging_capacity::CycleSummaryStats
# mean_discharging_capacity::DiagnosticSummaryStats
# mean_discharging_dQdV::DiagnosticSummaryStats
# mean_discharging_energy::DiagnosticSummaryStats
# mean_ocv::HPPCResistanceVoltageFeatures
# mean_v_diff::HPPCResistanceVoltageFeatures
# min_charging_capacity::DiagnosticSummaryStats
# min_charging_dQdV::DiagnosticSummaryStats
# min_charging_energy::CycleSummaryStats
# min_charging_energy::DiagnosticSummaryStats
# min_discharging_capacity::CycleSummaryStats
# min_discharging_capacity::DiagnosticSummaryStats
# min_discharging_dQdV::DiagnosticSummaryStats
# min_discharging_energy::DiagnosticSummaryStats
# min_ocv::HPPCResistanceVoltageFeatures
# min_v_diff::HPPCResistanceVoltageFeatures
# nominal_capacity_by_median::DeltaQFastCharge
# r_c_0s_00::HPPCResistanceVoltageFeatures
# r_c_0s_10::HPPCResistanceVoltageFeatures
# r_c_0s_20::HPPCResistanceVoltageFeatures
# r_c_0s_30::HPPCResistanceVoltageFeatures
# r_c_0s_40::HPPCResistanceVoltageFeatures
# r_c_0s_50::HPPCResistanceVoltageFeatures
# r_c_0s_60::HPPCResistanceVoltageFeatures
# r_c_0s_70::HPPCResistanceVoltageFeatures
# r_c_0s_80::HPPCResistanceVoltageFeatures
# r_c_3s_00::HPPCResistanceVoltageFeatures
# r_c_3s_10::HPPCResistanceVoltageFeatures
# r_c_3s_20::HPPCResistanceVoltageFeatures
# r_c_3s_30::HPPCResistanceVoltageFeatures
# r_c_3s_40::HPPCResistanceVoltageFeatures
# r_c_3s_50::HPPCResistanceVoltageFeatures
# r_c_3s_60::HPPCResistanceVoltageFeatures
# r_c_3s_70::HPPCResistanceVoltageFeatures
# r_c_3s_80::HPPCResistanceVoltageFeatures
# r_c_end_00::HPPCResistanceVoltageFeatures
# r_c_end_10::HPPCResistanceVoltageFeatures
# r_c_end_20::HPPCResistanceVoltageFeatures
# r_c_end_30::HPPCResistanceVoltageFeatures
# r_c_end_40::HPPCResistanceVoltageFeatures
# r_c_end_50::HPPCResistanceVoltageFeatures
# r_c_end_60::HPPCResistanceVoltageFeatures
# r_c_end_70::HPPCResistanceVoltageFeatures
# r_c_end_80::HPPCResistanceVoltageFeatures
# r_d_0s_00::HPPCResistanceVoltageFeatures
# r_d_0s_10::HPPCResistanceVoltageFeatures
# r_d_0s_20::HPPCResistanceVoltageFeatures
# r_d_0s_30::HPPCResistanceVoltageFeatures
# r_d_0s_40::HPPCResistanceVoltageFeatures
# r_d_0s_50::HPPCResistanceVoltageFeatures
# r_d_0s_60::HPPCResistanceVoltageFeatures
# r_d_0s_70::HPPCResistanceVoltageFeatures
# r_d_0s_80::HPPCResistanceVoltageFeatures
# r_d_3s_00::HPPCResistanceVoltageFeatures
# r_d_3s_10::HPPCResistanceVoltageFeatures
# r_d_3s_20::HPPCResistanceVoltageFeatures
# r_d_3s_30::HPPCResistanceVoltageFeatures
# r_d_3s_40::HPPCResistanceVoltageFeatures
# r_d_3s_50::HPPCResistanceVoltageFeatures
# r_d_3s_60::HPPCResistanceVoltageFeatures
# r_d_3s_70::HPPCResistanceVoltageFeatures
# r_d_3s_80::HPPCResistanceVoltageFeatures
# r_d_end_00::HPPCResistanceVoltageFeatures
# r_d_end_10::HPPCResistanceVoltageFeatures
# r_d_end_20::HPPCResistanceVoltageFeatures
# r_d_end_30::HPPCResistanceVoltageFeatures
# r_d_end_40::HPPCResistanceVoltageFeatures
# r_d_end_50::HPPCResistanceVoltageFeatures
# r_d_end_60::HPPCResistanceVoltageFeatures
# r_d_end_70::HPPCResistanceVoltageFeatures
# r_d_end_80::HPPCResistanceVoltageFeatures
# skew_charging_capacity::DiagnosticSummaryStats
# skew_charging_dQdV::DiagnosticSummaryStats
# skew_charging_energy::CycleSummaryStats
# skew_charging_energy::DiagnosticSummaryStats
# skew_discharging_capacity::CycleSummaryStats
# skew_discharging_capacity::DiagnosticSummaryStats
# skew_discharging_dQdV::DiagnosticSummaryStats
# skew_discharging_energy::DiagnosticSummaryStats
# skew_ocv::HPPCResistanceVoltageFeatures
# skew_v_diff::HPPCResistanceVoltageFeatures
# slope_discharge_capacity_cycle_number_2:100::DeltaQFastCharge
# slope_discharge_capacity_cycle_number_91:100::DeltaQFastCharge
# square_charging_capacity::DiagnosticSummaryStats
# square_charging_dQdV::DiagnosticSummaryStats
# square_charging_energy::CycleSummaryStats
# square_charging_energy::DiagnosticSummaryStats
# square_discharging_capacity::CycleSummaryStats
# square_discharging_capacity::DiagnosticSummaryStats
# square_discharging_dQdV::DiagnosticSummaryStats
# square_discharging_energy::DiagnosticSummaryStats
# sum_ocv::HPPCResistanceVoltageFeatures
# sum_square_ocv::HPPCResistanceVoltageFeatures
# sum_square_v_diff::HPPCResistanceVoltageFeatures
# sum_v_diff::HPPCResistanceVoltageFeatures
# trough_height_0_rpt_0.2C_1::RPTdQdVFeatures
# trough_height_1_rpt_0.2C_1::RPTdQdVFeatures
# trough_height_2_rpt_0.2C_1::RPTdQdVFeatures
# var_charging_capacity::DiagnosticSummaryStats
# var_charging_dQdV::DiagnosticSummaryStats
# var_charging_energy::CycleSummaryStats
# var_charging_energy::DiagnosticSummaryStats
# var_discharging_capacity::CycleSummaryStats
# var_discharging_capacity::DiagnosticSummaryStats
# var_discharging_dQdV::DiagnosticSummaryStats
# var_discharging_energy::DiagnosticSummaryStats
# var_ocv::HPPCResistanceVoltageFeatures
# var_v_diff::HPPCResistanceVoltageFeatures
# seq_num
# charge_constant_current_1::ExclusionCriteria
# charge_constant_current_1::ExclusionCriteria.1
# charge_constant_current_2::ExclusionCriteria
# charge_constant_current_2::ExclusionCriteria.1
# charge_constant_voltage_time::ExclusionCriteria
# charge_constant_voltage_time::ExclusionCriteria.1
# charge_cutoff_voltage::ExclusionCriteria
# charge_cutoff_voltage::ExclusionCriteria.1
# discharge_constant_current::ExclusionCriteria
# discharge_constant_current::ExclusionCriteria.1
# discharge_cutoff_voltage::ExclusionCriteria
# discharge_cutoff_voltage::ExclusionCriteria.1
# charge_constant_current_1::ExclusionCriteria.2
# charge_constant_current_1::ExclusionCriteria.3
# charge_constant_current_2::ExclusionCriteria.2
# charge_constant_current_2::ExclusionCriteria.3
# charge_constant_voltage_time::ExclusionCriteria.2
# charge_constant_voltage_time::ExclusionCriteria.3
# charge_cutoff_voltage::ExclusionCriteria.2
# charge_cutoff_voltage::ExclusionCriteria.3
# discharge_constant_current::ExclusionCriteria.2
# discharge_constant_current::ExclusionCriteria.3
# discharge_cutoff_voltage::ExclusionCriteria.2
# discharge_cutoff_voltage::ExclusionCriteria.3
